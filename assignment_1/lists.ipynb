# %%
grades = [15, 18, 12, 20, 16]

print("Lista original:", grades)
# Out:
# Lista original: [15, 18, 12, 20, 16]

# %%
grades.append(17)
print(grades)
# Out:
# [15, 18, 12, 20, 16, 17]

# %%
grades.sort()
print(grades)
# Out:
# [12, 15, 16, 17, 18, 20]

# %%
print("Nota más alta:", max(grades))
print("Nota más baja:", min(grades))
print("Cantidad de notas:", len(grades))
# Out:
# Nota más alta: 20
# Nota más baja: 12
# Cantidad de notas: 6

# %%
print("Lista final:", grades)
# Out:
# Lista final: [12, 15, 16, 17, 18, 20]
